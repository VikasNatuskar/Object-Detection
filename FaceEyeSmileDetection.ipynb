# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('specs.jpg')

smile_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_smile.xml')
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_eye_tree_eyeglasses.xml')

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

face = face_cascade.detectMultiScale(gray, 1.03, 30)
img2 = image.copy()

for (x,y,w,h) in face:
    cv2.rectangle(img2, (x,y),((x+w),(y+h)), (0,255,0),2)
    
    smile = smile_cascade.detectMultiScale(gray, 1.5, 40)
    for (sx,sy,sw,sh) in smile:
        cv2.rectangle(img2,(sx,sy),((sx+sw),(sy+sh)),(0,255,0),2)
        
    eyes = eye_cascade.detectMultiScale(gray, 1.3,3)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(img2, (ex,ey),((ex+ew),(ey+eh)),(0,255,0),2)

# %%
plt.imshow(img2)
plt.axis('off')
plt.show()
